# %%
import numpy as np 
import cv2 as cv
# Out:
# Running cells with '.venv (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/REC/Desktop/gesture-music/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
